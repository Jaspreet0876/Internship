# %% [markdown]
# # Q1. & Q2.

# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import sys
from selenium.common import exceptions
import io
from selenium.webdriver.chrome.options import Options
import requests
import re

# %%
driver=webdriver.Chrome("chromedriver")

# %%
url="https://www.amazon.in/"
driver.get(url)
driver.maximize_window()

# %%
search_product= driver.find_element_by_id("twotabsearchtextbox")
search_product
search_product.send_keys(input("enter input: "))
# Out:
# enter input: headphones

# %%
search_btn=driver.find_element_by_id("nav-search-submit-button")
search_btn
search_btn.click()

# %%
Product_url=[]
for i in range(0,3):
    product_url=driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']//a")
    for i in product_url:
        Product_url.append(i.get_attribute('href'))
    next_btn=driver.find_element_by_xpath("//li[@class='a-last']/a")
    next_btn.click()
    time.sleep(3)

# %%
len(Product_url)
# Out:
# 70

# %%
Brand=[]
Name=[]
Rating=[]
No_of_ratings=[]
Price=[]
Return=[]
Expected_delivery=[]
Availability=[]
Other_details=[]

# %%
for i in Product_url:
    driver.get(i)
    try:
        brand=driver.find_element_by_xpath("//td[@class='a-span9']/span")
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-')
        
    try:
        name=driver.find_element_by_xpath("//div[@id='titleSection']//span")
        Name.append(name.text)
    except NoSuchElementException:
        Name.append('-')
    
    try:
        rating=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']//span")
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append("No Rating")
        
    try:
        no_of_ratings=driver.find_element_by_xpath("//div[@class='a-row a-spacing-medium averageStarRatingNumerical']//span")
        No_of_ratings.append(no_of_ratings.text)
    except NoSuchElementException:
        No_of_ratings.append('-')
        
    try:
        price=driver.find_element_by_xpath("//span[@class='a-size-medium a-color-price priceBlockDealPriceString' or @class='a-size-medium a-color-price priceBlockBuyingPriceString']")
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')
        
    try:
        return_=driver.find_element_by_xpath("//div[@data-name='RETURNS_POLICY']//span//div[2]//a")
        Return.append(return_.text)
    except NoSuchElementException:
        Return.append('-')
        
    try:
        expected_del=driver.find_element_by_xpath("//div[@id='ddmDeliveryMessage']//b")
        Expected_delivery.append(expected_del.text)
    except NoSuchElementException:
        Expected_delivery.append('-')
        
    try:
        availability=driver.find_element_by_xpath("//div[@class='a-section a-spacing-base }']//span")
        Availability.append(availability.text)
    except NoSuchElementException:
        Availability.append('-')
        
    try:
        other_details=driver.find_element_by_xpath("//div[@class='a-section a-spacing-medium a-spacing-top-small']//ul")
        Other_details.append(other_details.text)
    except NoSuchElementException:
        Other_details.append('-')

# %%
headphone=pd.DataFrame({})
headphone['Brand']=Brand
headphone['Product_name']=Name
headphone['Rating']=Rating
headphone['No of rating']=No_of_ratings
headphone['Price']=Price
headphone['Return']=Return
headphone['Expected_delivery']=Expected_delivery
headphone['availability']=Availability
headphone['Product_urls']=Product_url
headphone['Other_details']=Other_details
headphone
# Out:
#           Brand                                       Product_name  \
# 0         Shure  Shure AONIC 50 Wireless Noise Canceling Headph...
# 1         Shure  Shure AONIC 50 Wireless Noise Cancelling Headp...
# 2          BoAt  boAt Bassheads 900 Wired On Ear Headphones wit...
# 3          BoAt  boAt Rockerz 510 Wireless Bluetooth On Ear Hea...
# 4     ZEBRONICS  ZEBRONICS Zeb-Thunder Wireless Bluetooth Over ...
# ..          ...                                                ...
# 65       Tribit  Tribit Wireless Bluetooth Headphones Over Ear,...
# 66        PTron  pTron Bassbuds Jade Gaming True Wireless Headp...
# 67      OneOdio  OneOdio Wired Over Ear Headphones - Adapter Fr...
# 68      Lapcare  LAPCARE Stereo Headset LWS-004 Headphone with ...
# 69  Boult Audio  Boult Audio ProBass Qcharge in-Ear Earphones w...
#
#           Rating           No of rating       Price                   Return  \
# 0   4.2 out of 5      40 global ratings  ₹27,990.00       7 Days Replacement
# ...

# %% [markdown]
# # Q3.

# %%
chrome_options=Options()
chrome_options.add_argument('--disable-blink-features=AutomationControlled')
driver= webdriver.Chrome("chromedriver",options=chrome_options)

# %%
url="https://images.google.com/"

# %%
urls=[]
data=[]
search_items=["Fruits","Cars","Machine Learning"]
for item in search_items:
    driver.get(url)
    time.sleep(3)
    search_image=driver.find_element_by_tag_name("input")
    search_image.send_keys(str(item))
    search_btn=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
    search_btn.click()
  
    
    for j in range(500):
        driver.execute_script("window.scrollBy(0,100)")
        images = driver.find_elements_by_xpath("//img[@class='rg_i Q4LuWd']")
    img_url = []
    for img in images:
        source= img.get_attribute('src')
        if source is not None:
                if(source[0:4] == 'http'):
                    img_url.append(source)
    for i in img_url[:100]:
        urls.append(i)
for i in range(len(urls)):
    if i >= 300:
        break
    print("Obtaining {0} of {1} images".format(i,300))
    response=requests.get(urls[i])
    file= open(r"D:\images"+str(i)+".jpg","wb")
        
    file.write(response.content)
# Out:
# Obtaining 0 of 300 images
# Obtaining 1 of 300 images
# Obtaining 2 of 300 images
# Obtaining 3 of 300 images
# Obtaining 4 of 300 images
# Obtaining 5 of 300 images
# Obtaining 6 of 300 images
# Obtaining 7 of 300 images
# Obtaining 8 of 300 images
# Obtaining 9 of 300 images
# Obtaining 10 of 300 images
# Obtaining 11 of 300 images
# Obtaining 12 of 300 images
# Obtaining 13 of 300 images
# Obtaining 14 of 300 images
# Obtaining 15 of 300 images
# Obtaining 16 of 300 images
# Obtaining 17 of 300 images
# Obtaining 18 of 300 images
# Obtaining 19 of 300 images
# Obtaining 20 of 300 images
# Obtaining 21 of 300 images
# Obtaining 22 of 300 images
# Obtaining 23 of 300 images
# Obtaining 24 of 300 images
# Obtaining 25 of 300 images
# Obtaining 26 of 300 images
# Obtaining 27 of 300 images
# Obtaining 28 of 300 images
# Obtaining 29 of 300 images
# Obtaining 30 of 300 images
# Obtaining 31 of 300 images
# Obtaining 32 of 300 images
# Obtaining 33 of 300 images
# ...

# %% [markdown]
# # Q4.

# %%
driver=webdriver.Chrome("chromedriver")

# %%
url="https://www.flipkart.com/"
driver.get(url)
driver.maximize_window()

# %%
search_product= driver.find_element_by_xpath("//input[@title='Search for products, brands and more']")
search_product
search_product.send_keys('smartphones')

# %%
search_btn=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search_btn
search_btn.click()

# %%
Product_url=[]
product_url=driver.find_elements_by_xpath("//div[@class='_2kHMtA']//a")
for i in product_url:
    Product_url.append(i.get_attribute('href'))

# %%
len(Product_url)
# Out:
# 24

# %%
Brand=[]
Name=[]
Color=[]
RAM=[]
Price=[]
Storage_rom=[]
Primary_cam=[]
Secondary_cam=[]
Display_size=[]
Display_res=[]
Processor=[]
Cores=[]
Battery=[]

# %%
for i in Product_url:
    driver.get(i)
    readmore=driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']")
    readmore.click()
    try:
        
        ram=driver.find_element_by_xpath("//td[text()='RAM']//parent::tr[@class='_1s_Smc row']//ul//li")
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('-')

# %%
for i in Product_url:
    driver.get(i)
    readmore=driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']")
    readmore.click()
    
    try:
        name=driver.find_element_by_xpath("//span[@class='B_NuCI']")
        Name.append(name.text)
    except NoSuchElementException:
        Name.append('-')
        
    try:
        brand=driver.find_element_by_xpath("//h1[@class='yhB1nd']")
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-')
    
    try:
        color=driver.find_element_by_xpath("//td[text()='Color']//parent::tr[@class='_1s_Smc row']//ul//li")
        
        Color.append(color.text)
    except NoSuchElementException:
        Color.append("-")
        
    try:
        ram=driver.find_element_by_xpath("//td[text()='RAM']//parent::tr[@class='_1s_Smc row']//ul//li")
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('-')
        
    try:
        price=driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')
        
    try:
        storage=driver.find_element_by_xpath("//td[text()='Internal Storage']//parent::tr[@class='_1s_Smc row']//ul//li")
        Storage_rom.append(storage.text)
    except NoSuchElementException:
        Storage_rom.append('-')
        
    try:
        primary_cam=driver.find_element_by_xpath("//td[text()='Primary Camera']//parent::tr[@class='_1s_Smc row']//ul//li")
        Primary_cam.append(primary_cam.text)
    except NoSuchElementException:
        Primary_cam.append('-')
        
    try:
        secondary_cam=driver.find_element_by_xpath("//td[text()='Secondary Camera']//parent::tr[@class='_1s_Smc row']//ul//li")
        Secondary_cam.append(secondary_cam.text)
    except NoSuchElementException:
        Secondary_cam.append('-')
        
    try:
        display_size=driver.find_element_by_xpath("//td[text()='Display Size']//parent::tr[@class='_1s_Smc row']//ul//li")
        Display_size.append(display_size.text)
    except NoSuchElementException:
        Display_size.append('-')
        
    try:
        display_res=driver.find_element_by_xpath("//td[text()='Resolution']//parent::tr[@class='_1s_Smc row']//ul//li")
        Display_res.append(display_res.text)
    except NoSuchElementException:
        Display_res.append('-')
        
    try:
        processor=driver.find_element_by_xpath("//td[text()='Processor Type']//parent::tr[@class='_1s_Smc row']//ul//li")
        Processor.append(processor.text)
    except NoSuchElementException:
        Processor.append('-')
        
    try:
        cores=driver.find_element_by_xpath("//td[text()='Processor Core']//parent::tr[@class='_1s_Smc row']//ul//li")
        Cores.append(cores.text)
    except NoSuchElementException:
        Cores.append('-')
        
    try:
        battery=driver.find_element_by_xpath("//td[text()='Battery Capacity']//parent::tr[@class='_1s_Smc row']//ul//li")
        Battery.append(battery.text)
    except NoSuchElementException:
        Battery.append('-')

# %%
smartphone=pd.DataFrame({})
smartphone['Brand']=Brand
smartphone['Name']=Name
smartphone['Color']=Color
smartphone['RAM']=RAM
smartphone['ROM']=Storage_rom
smartphone['Primary_cam']=Primary_cam
smartphone['Secondary_cam']=Secondary_cam
smartphone['Display_size']=Display_size
smartphone['Resolution']=Display_res
smartphone['Processor']=Processor
smartphone['Cores']=Cores
smartphone['Battery']=Battery
smartphone['Price']=Price
smartphone['Product_url']=Product_url
smartphone
# Out:
#                                                 Brand  \
# 0            POCO C3 (Matte Black, 64 GB)  (4 GB RAM)
# 1            POCO C3 (Arctic Blue, 64 GB)  (4 GB RAM)
# 2           realme C20 (Cool Grey, 32 GB)  (2 GB RAM)
# 3           realme C20 (Cool Blue, 32 GB)  (2 GB RAM)
# 4          REDMI 9i (Nature Green, 64 GB)  (4 GB RAM)
# 5      realme C11 2021 (Cool Blue, 32 GB)  (2 GB RAM)
# 6      realme C11 2021 (Cool Grey, 32 GB)  (2 GB RAM)
# 7   realme Narzo 30 5G (Racing Blue, 64 GB)  (4 GB...
# 8   realme Narzo 30 5G (Racing Silver, 64 GB)  (4 ...
# 9      realme C11 2021 (Cool Blue, 64 GB)  (4 GB RAM)
# 10            POCO C3 (Lime Green, 32 GB)  (3 GB RAM)
# 11             POCO M3 (Cool Blue, 64 GB)  (4 GB RAM)
# 12    REDMI 9 Power (Blazing Blue, 64 GB)  (4 GB RAM)
# 13           POCO C3 (Arctic Blue, 32 GB)  (3 GB RAM)
# 14        realme C21Y (Cross Blue, 64 GB)  (4 GB RAM)
# 15       realme C21Y (Cross Black, 64 GB)  (4 GB RAM)
# ...

# %% [markdown]
# # Q5.

# %%
url="https://www.google.com/maps"
driver.get(url)
driver.maximize_window()

# %%
search_bar=driver.find_element_by_xpath("//input[@id='searchboxinput' and @class='tactile-searchbox-input']")
place=str(input('enter the name of the place'))
search_bar.send_keys(place)
submit_btn=driver.find_element_by_xpath("//button[@id='searchbox-searchbutton' and @class='searchbox-searchbutton']")
submit_btn.click()
current_url= driver.current_url


try:
    lat = re.findall('(\d+(\.\d*)?)', current_url)[0]
    lon = re.findall('(\d+(\.\d*)?)', current_url)[1]
    print("Geospatial Coordinates for", place + " on Google Maps are: ")
    print("Latitude  :", lat[0])
    print("Longitude :", lon[0])
    
except Exception as e:
    print("Error: ", str(e))
# Out:
# enter the name of the placeindore
# Geospatial Coordinates for indore on Google Maps are:
# Latitude  : 22.6891478
# Longitude : 75.8650143

# %% [markdown]
# # Q6.

# %%
url ="https://trak.in/"
driver.get(url)
driver.maximize_window()

# %%
button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(button)

# %%
Date=[]
Name=[]
Industry=[]
Sub_vertical=[]
City=[]
Investor=[]
Investment_type=[]
Amount=[]


date= driver.find_elements_by_xpath("//table[@id='tablepress-48']//td[@class='column-2']")
for i in date:
    Date.append(i.text)    
name= driver.find_elements_by_xpath("//table[@id='tablepress-48']//td[@class='column-3']")
for i in name:
    Name.append(i.text)    
industry= driver.find_elements_by_xpath("//table[@id='tablepress-48']//td[@class='column-4']")
for i in industry:
    Industry.append(i.text)    
sub_vertical= driver.find_elements_by_xpath("//table[@id='tablepress-48']//td[@class='column-5']")
for i in sub_vertical:
    Sub_vertical.append(i.text)    
city= driver.find_elements_by_xpath("//table[@id='tablepress-48']//td[@class='column-6']")
for i in city:
    City.append(i.text)    
investor= driver.find_elements_by_xpath("//table[@id='tablepress-48']//td[@class='column-7']")
for i in investor:
    Investor.append(i.text)    
investment_type= driver.find_elements_by_xpath("//table[@id='tablepress-48']//td[@class='column-8']")
for i in investment_type:
    Investment_type.append(i.text)    
amount= driver.find_elements_by_xpath("//table[@id='tablepress-48']//td[@class='column-9']")
for i in amount:
    Amount.append(i.text)
    
#August month
date= driver.find_elements_by_xpath("//table[@id='tablepress-49']//td[@class='column-2']")
for i in date:
    Date.append(i.text)    
name= driver.find_elements_by_xpath("//table[@id='tablepress-49']//td[@class='column-3']")
for i in name:
    Name.append(i.text)    
industry= driver.find_elements_by_xpath("//table[@id='tablepress-49']//td[@class='column-4']")
for i in industry:
    Industry.append(i.text)    
sub_vertical= driver.find_elements_by_xpath("//table[@id='tablepress-49']//td[@class='column-5']")
for i in sub_vertical:
    Sub_vertical.append(i.text)    
city= driver.find_elements_by_xpath("//table[@id='tablepress-49']//td[@class='column-6']")
for i in city:
    City.append(i.text)    
investor= driver.find_elements_by_xpath("//table[@id='tablepress-49']//td[@class='column-7']")
for i in investor:
    Investor.append(i.text)    
investment_type= driver.find_elements_by_xpath("//table[@id='tablepress-49']//td[@class='column-8']")
for i in investment_type:
    Investment_type.append(i.text)    
amount= driver.find_elements_by_xpath("//table[@id='tablepress-49']//td[@class='column-9']")
for i in amount:
    Amount.append(i.text)
    
#September month
date= driver.find_elements_by_xpath("//table[@id='tablepress-50']//td[@class='column-2']")
for i in date:
    Date.append(i.text)    
name= driver.find_elements_by_xpath("//table[@id='tablepress-50']//td[@class='column-3']")
for i in name:
    Name.append(i.text)    
industry= driver.find_elements_by_xpath("//table[@id='tablepress-50']//td[@class='column-4']")
for i in industry:
    Industry.append(i.text)    
sub_vertical= driver.find_elements_by_xpath("//table[@id='tablepress-50']//td[@class='column-5']")
for i in sub_vertical:
    Sub_vertical.append(i.text)    
city= driver.find_elements_by_xpath("//table[@id='tablepress-50']//td[@class='column-6']")
for i in city:
    City.append(i.text)    
investor= driver.find_elements_by_xpath("//table[@id='tablepress-50']//td[@class='column-7']")
for i in investor:
    Investor.append(i.text)    
investment_type= driver.find_elements_by_xpath("//table[@id='tablepress-50']//td[@class='column-8']")
for i in investment_type:
    Investment_type.append(i.text)    
amount= driver.find_elements_by_xpath("//table[@id='tablepress-50']//td[@class='column-9']")
for i in amount:
    Amount.append(i.text)

# %%
trak=pd.DataFrame({})
trak['Dates']=Date
trak['Name']=Name
trak['Industry_vertical']=Industry
trak['Sub_vertical']=Sub_vertical
trak['City']=City
trak['Investor']=Investor
trak['Investment_type']=Investment_type
trak['Amount']=Amount
trak
# Out:
#          Dates                       Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  08/09/2020                     Byju’s
# ...

# %% [markdown]
# # Q7.

# %%
url = "https://www.digit.in/"
driver.get(url)

# %%
best_gaming_lap = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]")
best_gaming_lap.click()

# %%
Name = []
OS = []
Display = []
Processor = []
Memory = []
Weight = []
Dimension = []
Graphic_pro = []
Price = []

# %%
name=driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[1]")
for i in name:
    Name.append(i.text)
    
try:
    os = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[3]//td[3]")
    for i in os:
        OS.append(i.text)
except NoSuchElementException:
    pass


try:
    display = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[4]//td[3]")
    for i in display:
        Display.append(i.text)
except NoSuchElementException:
    pass


try:
    processor = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[5]//td[3]")
    for i in processor:
        Processor.append(i.text)
except NoSuchElementException:
    pass


try:
    memory = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[6]//td[3]")
    for i in memory:
        Memory.append(i.text)
except NoSuchElementException:
    pass


try:
    weight = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[7]//td[3]")
    for i in weight:
        Weight.append(i.text)
except NoSuchElementException:
    pass


try:
    dimension = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[8]//td[3]")
    for i in dimension:
        Dimension.append(i.text)
except NoSuchElementException:
    pass


try:
    graphic = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[9]//td[3]")
    for i in graphic:
        Graphic_pro.append(i.text)
except NoSuchElementException:
    pass


try:
    price = driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[3]")
    for i in price:
        Price.append(i.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# %%
best_laptop=pd.DataFrame({})
best_laptop["Name"]=Name
best_laptop["OS"]=OS
best_laptop["Display"]=Display
best_laptop["Processor"]=Processor
best_laptop["Memory"]=Memory
best_laptop["Weight"]=Weight
best_laptop["Dimension"]=Dimension
best_laptop["Graphic_pro"]=Graphic_pro
best_laptop["Price"]=Price
best_laptop
# Out:
#                         Name               OS              Display  \
# 0      Alienware Area 51M R2  Windows 10 Home  17.3" (1920 x 1080)
# 1           Alienware m15 R3  Windows 10 Home  15.6" (3840 x 2160)
# 2     ASUS ROG Strix Scar 15  Windows 10 Home  15.6" (1920 x 1080)
# 3      Asus ROG Zephyrus G14  Windows 10 Home    14" (1920 x 1080)
# 4           Lenovo Legion 5i   Windows 10 Pro  15.6" (1920 x 1080)
# 5   ASUS ROG ZEPHYRUS DUO 15       Windows 10  15.6" (3840 x 1100)
# 6       Acer Aspire 7 gaming  Windows 10 Home  15.6" (1920 x 1080)
# 7      Alienware Area 51M R2  Windows 10 Home  17.3" (1920 x 1080)
# 8           Alienware m15 R3  Windows 10 Home  15.6" (3840 x 2160)
# 9     ASUS ROG Strix Scar 15  Windows 10 Home  15.6" (1920 x 1080)
# 10     Asus ROG Zephyrus G14  Windows 10 Home    14" (1920 x 1080)
# 11          Lenovo Legion 5i   Windows 10 Pro  15.6" (1920 x 1080)
# 12  ASUS ROG ZEPHYRUS DUO 15       Windows 10  15.6" (3840 x 1100)
# ...

# %% [markdown]
# # Q8.

# %%
url = 'https://www.forbes.com/'
driver.get(url)

# %%
opt= driver.find_element_by_xpath("//button[@class='icon--hamburger']")
opt.click()

# %%
billionares = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
billionares.click()

# %%
world_billionare = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_billionare.click()

# %%
Rank = []
try:
    rank = driver.find_elements_by_xpath("//div[@class='rank']")
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    pass


Names = []
try:
    name = driver.find_elements_by_xpath("//div[@class='personName']")
    for i in name:
        Names.append(i.text)
except NoSuchElementException:
    pass


Net_worth = []
try:
    worth = driver.find_elements_by_xpath("//div[@class='netWorth']")
    for i in worth:
        Net_worth.append(i.text)
except NoSuchElementException:
    pass


Age = []
try:
    age = driver.find_elements_by_xpath("//div[@class='age']")
    for i in age:
        Age.append(i.text)
except NoSuchElementException:
    Age.append('-')
    

Citizenship = []
try:
    cit = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for i in cit:
        Citizenship.append(i.text)
except NoSuchElementException:
    Citizenship.append('-')
    

source = []
try:
    src = driver.find_elements_by_xpath("//div[@class='source-column']")
    for i in src:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
    

Industry = []
try:
    industry = driver.find_elements_by_xpath("//div[@class='category']")
    for i in industry:
        Industry.append(i.text)
except NoSuchElementException:
    Industry.append('-')

# %%
forbes=pd.DataFrame({})
forbes["Rank"]=Rank
forbes["Name"]=Names
forbes["Net_worth"]=Net_worth
forbes["Age"]=Age
forbes["Citizenship"]=Citizenship
forbes["Source"]=source
forbes["Industry"]=Industry
forbes
# Out:
#      Rank                      Name Net_worth Age    Citizenship  \
# 0      1.                Jeff Bezos    $177 B      United States
# 1      2.                 Elon Musk    $151 B      United States
# 2      3.  Bernard Arnault & family    $150 B             France
# 3      4.                Bill Gates    $124 B      United States
# 4      5.           Mark Zuckerberg     $97 B      United States
# ..    ...                       ...       ...  ..            ...
# 195  195.           Harry Triguboff   $11.2 B          Australia
# 196  197.     Leonid Fedun & family   $11.1 B             Russia
# 197  197.                 Eyal Ofer   $11.1 B             Israel
# 198  197.              Evan Spiegel   $11.1 B      United States
# 199  200.     Luis Carlos Sarmiento     $11 B           Colombia
#
#                     Source Industry
# 0                   Amazon
# 1            Tesla, SpaceX
# 2                     LVMH
# 3                Microsoft
# 4                 Facebook
# ...

# %% [markdown]
# # Q9.

# %%
driver=webdriver.Chrome("chromedriver")

# %%
url="https://www.youtube.com/"
driver.get(url)
driver.maximize_window()

# %%
search= driver.find_element_by_xpath("//input[@id='search' and @class='ytd-searchbox']")
search
search.send_keys('whatever it takes')

# %%
search_btn=driver.find_element_by_xpath("//button[@class='style-scope ytd-searchbox' and @id='search-icon-legacy']")
search_btn
search_btn.click()

# %%
link_click=driver.find_element_by_xpath("//yt-formatted-string[@class='style-scope ytd-video-renderer']")
link_click.click()

# %%
comment_section=driver.find_element_by_xpath('//*[@id="comments"]')
driver.execute_script("arguments[0].scrollIntoView();", comment_section)
time.sleep(7)

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,1000)")

# %%
Comments=[]
Upvotes=[]
Times=[]

try:
    comment=driver.find_elements_by_xpath("//*[@id='content-text']")[:500]
    for i in comment:
        Comments.append(i.text)
except NoSuchElementException:
    Comments.append('-')
time.sleep(5)

try:
    upvotes=driver.find_elements_by_xpath("//*[@id='vote-count-middle']")[:500]
    for i in upvotes:
        Upvotes.append(i.text)
except NoSuchElementException:
    Upvotes.append('-')
time.sleep(5)

try:
    timing=driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']")[:500]
    
    for i in timing:
        Times.append(i.text.replace('(edited)',''))
except NoSuchElementException:
    Times.append('-')
time.sleep(5)

# %%
youtube=pd.DataFrame({})
youtube['Comments']=Comments
youtube['Upvotes']=Upvotes
youtube['timeline of comment']=Times
youtube
# Out:
#                                               Comments Upvotes  \
# 0    My favourite track this year..\nI do whatever ...     14K
# 1    Nostalgia is one of the most saddest and great...    1.3K
# 2    A message to the future generations. Don't let...     337
# 3                                              Somzera       2
# 4    If you’re watching this in 2021, I love you an...     245
# ..                                                 ...     ...
# 495       This song makes me Happy, whatever it takes     1.3K
# 496  Day 30 of listening to this masterpiece everyd...       2
# 497  bruh, all my favourite edits have imagine drag...
# 498  уже три года прошло...\nЭТО ПРОСТО ПИЗДЕЦ\nВРЕ...      13
# 499  My grandpa tell to my father about Beatles, th...       1
#
#     timeline of comment
# 0           3 years ago
# 1          2 months ago
# 2            1 week ago
# 3           1 month ago
# 4           2 weeks ago
# ..                  ...
# 495         3 years ago
# ...

# %% [markdown]
# # Q10.

# %%
url = "https://www.hostelworld.com/"
driver.get(url)

# %%
search_loc = driver.find_element_by_id('search-input-field')
search_loc.send_keys("London")

# %%
london = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div')
london.click()

# %%
search_btn = driver.find_element_by_id('search-button')
search_btn.click()

# %%
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description =[]
product_url = []

for i in driver.find_elements_by_xpath("//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
    i.click()
    time.sleep(4)
    
    
    try:
        name = driver.find_elements_by_xpath("//h2[@class='title title-6']")
        for i in name:
            hostel_name.append(i.text)
    except NoSuchElementException:
        hostel_name.append('-')
        
       
    try:
        dist = driver.find_elements_by_xpath("//div[@class='subtitle body-3']//a//span[1]")
        for i in dist:
            distance.append(i.text.replace('Hostel - ',''))
    except NoSuchElementException:
        distance.append('-')
        
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
        
    
        try:
            pvt_price = driver.find_element_by_xpath("//a[@class='prices']//div[1]//div")
            pvt_prices.append(pvt_price.text)
        except NoSuchElementException:
            pvt_prices.append('-')
            
    
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
        try:
            dorms = driver.find_element_by_xpath("//a[@class='prices']//div[2]//div")
            dorms_price.append(dorms.text)
        except NoSuchElementException:
            dorms_price.append('-')
            
    
    try:
        fac1 = driver.find_elements_by_xpath("//div[@class='has-wifi']")
        fac2 = driver.find_elements_by_xpath("//div[@class='has-sanitation']")
        for i in fac1:
            for j in fac2:
                facilities.append(i.text +', '+ j.text )
    except NoSuchElementException:
        facilities.append('-')
        
    
    p_url = driver.find_elements_by_xpath("//div[@class='prices-col']//a[2]")
    for i in p_url:
        product_url.append(i.get_attribute('href'))

for i in product_url:
    driver.get(i)
    time.sleep(3)
    
    
    try:
        driver.find_element_by_xpath("//a[@class='toggle-content']").click()
        time.sleep(5)
    except NoSuchElementException:
        pass
    
    
    try:
        rat = driver.find_element_by_xpath("//div[@class='score orange big' or @class='score gray big']")
        rating.append(rat.text)
    except NoSuchElementException:
        rating.append('-')
        
           
    try:
        rws = driver.find_element_by_xpath("//div[@class='reviews']")
        reviews.append(rws.text.replace('Total Reviews',''))
    except NoSuchElementException:
        reviews.append('-')
        
    
    try:
        overall_rw = driver.find_element_by_xpath("//div[@class='keyword']//span")
        over_all.append(overall_rw.text)
    except NoSuchElementException:
        over_all.append('-')
        
     
    try:
        disc = driver.find_element_by_xpath("//div[@class='content']")
        description.append(disc.text)
    except NoSuchElementException:
        over_all.append('-')

# %%
hostel = list(zip(hostel_name,distance,rating,reviews,over_all,pvt_prices,dorms_price,facilities,description))       
Hostel = pd.DataFrame(hostel, columns = ["Hostel name","Distance from city centre","Ratings","Total reviews",
                                   "Overall review","Privates from price","Dorms from price","Facilities","Property Description"])
Hostel
# Out:
#                                Hostel name  \
# 0                   London Waterloo Hostel
# 1                 Barmy Badger Backpackers
# 2          Wombat's The City Hostel London
# 3                  Prime Backpackers Angel
# 4                        The Walrus Hostel
# ..                                     ...
# 61  Best Western Boltons London Kensington
# 62                        Park Hotel Essex
# 63                         Cranbrook Hotel
# 64                              St. Athans
# 65                        Aron Guest House
#
#                       Distance from city centre Ratings Total reviews  \
# 0                        0.7km from city centre     7.2         2420
# 1                        5.5km from city centre     9.7         1660
# 2                        3.6km from city centre     8.7        13198
# 3                        3.6km from city centre      10          514
# 4                        0.2km from city centre     8.1         3662
# ...
